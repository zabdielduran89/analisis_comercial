# %% [markdown]
# **Comentario del Revisor**
#
# Hola!
#
# Soy Juan Manuel Romero, pero siéntete libre de llamarme Juanma. Soy code reviewer en Tripleten y hoy estaré revisando tu entrega.
#
# Para simular la dinámica de un ambiente de trabajo, si veo algún error, en primer instancia solo los señalaré, dándote la oportunidad de encontrarlos y corregirlos por tu cuenta. En un trabajo real, el líder de tu equipo hará una dinámica similar. En caso de que no puedas resolver la tarea, te daré una información más precisa en la próxima revisión.
#
# Solo un aviso rápido: cuando estés revisando el proyecto, por favor deja mis comentarios originales tal como están. De esta manera, podemos seguir fácilmente el progreso y asegurarnos de que no se nos pase nada por alto. Y, si realizas algún cambio basado en mis comentarios, sería genial si pudieras resaltar esas actualizaciones para que se destaquen.
#
# Puedes encontrar mis comentarios en cajas verdes, amarillas o rojas como estas:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Éxito. Todo se ha hecho correctamente.
#
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Observaciones. Algunas recomendaciones.
#
# </div>
#
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Requiere corrección. El bloque requiere algunas correcciones. El trabajo no puede ser aceptado con los comentarios en rojo.
#
# </div>
#
# Puedes responderme usando esto:
#
# <div class="alert alert-block alert-info"> <b>Respuesta del estudiante.</b> <a class="tocSkip"></a> </div>

# %%
<div class="alert alert-block alert-success"> 
<b>COMENTARIO GENERAL #1</b> <a class="tocSkip"></a>

Felicidades []! Tu trabajo es excelente. 

Has completado todos los items necesarios para aprobar la entrega.

Sigue así!

</div>

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.
#
# * Leer los DataFrames y guardarlos en variables para generar las líneas de código

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo al separar la importación de bibliotecas de la carga de los datasets! Esto mejora la estructura y claridad de tu código.
#
# </div>

# %%
# leer conjuntos de datos en los DataFrames

# %%
instacart_orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';') # mostrar información del DataFrame
instacart_orders
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0        1515936   183418            11          6                 13
# 1        1690866   163593             5          5                 12
# 2        1454967    39980             4          5                 19
# 3        1768857    82516            56          0                 20
# 4        3007858   196724             2          4                 12
# ...          ...      ...           ...        ...                ...
# 478962   3210681     5617             5          1                 14
# 478963   3270802   112087             2          3                 13
# 478964    885349    82944            16          2                 11
# 478965    216274     4391             3          3                  8
# 478966   2071924     1730            18          1                 14
#
#         days_since_prior_order
# 0                         30.0
# 1                          9.0
# ...

# %%
products = pd.read_csv('/datasets/products.csv', sep=';') # mostrar información del DataFrame
products
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49689       49690                      HIGH PERFORMANCE ENERGY DRINK
# 49690       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 49691       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692       49693                             SPRING WATER BODY WASH
# 49693       49694                            BURRITO- STEAK & CHEESE
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %%
aisles = pd.read_csv('/datasets/aisles.csv', sep=';') # mostrar información del DataFrame
aisles
# Out:
#      aisle_id                       aisle
# 0           1       prepared soups salads
# 1           2           specialty cheeses
# 2           3         energy granola bars
# 3           4               instant foods
# 4           5  marinades meat preparation
# ..        ...                         ...
# 129       130    hot cereal pancake mixes
# 130       131                   dry pasta
# 131       132                      beauty
# 132       133  muscles joints pain relief
# 133       134  specialty wines champagnes
#
# [134 rows x 2 columns]

# %%
departments = pd.read_csv('/datasets/departments.csv', sep=';') # mostrar información del DataFrame
departments
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %%
order_products = pd.read_csv('/datasets/order_products.csv', sep=';') # mostrar información del DataFrame
order_products
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440               17.0          0
# 1          567889        1560                1.0          1
# 2         2261212       26683                1.0          1
# 3          491251        8670               35.0          1
# 4         2571142        1940                5.0          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290               12.0          1
# 4545003   1219554       21914                9.0          0
# 4545004    692640       47766                4.0          1
# 4545005    319435         691                8.0          1
# 4545006   1398151       28733                9.0          0
#
# [4545007 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Has omitido el uso de los métodos básicos de exploración de datos como `info` o `head`. Estos son cruciales para entender la estructura de los datos y detectar posibles problemas antes del análisis más detallado.
#
# </div>

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
#
# * Para que los datos puedan ser leídos fácilmente, es necesario ordenarlos por medio de un separador porque de lo contrario tendríamos datos un desorden en los DataFrames

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo al incluir conclusiones intermedias sobre la vista general de los datos
#
# </div>
#
# Como mejora, te sugiero hablar sobre el tipo de dato y posible causa o impacto de los valores faltantes (por ejemplo, si son errores de carga, datos opcionales, etc.), así como una idea preliminar de cómo podrías tratarlos (eliminación, imputación, etc.). Esto fortalece tu análisis descriptivo inicial.
#
# </div>

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
#
# * Utilizar el método .duplicated() .sort_values() y al final contar los duplicados permitirá que se puedan localizan y eliminar datos valores ausentes y podamos visualizar la información importante

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Es correcto que abordes primero los valores duplicados antes de llenar los valores ausentes. Si eliminas duplicados después, podrías haber trabajado innecesariamente en filas que no eran relevantes para el análisis. Esto te permite ahorrar tiempo y esfuerzo mientras aseguras que los datos sean consistentes desde el principio.
#
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
instacart_orders[instacart_orders['order_id'].duplicated(keep=False)].sort_values(by='order_id') # Revisa si hay pedidos duplicados
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 354993    391768    57671            19          3                  2
# 371905    391768    57671            19          3                  2
# 119251    408114    68324             4          3                  2
# 321100    408114    68324             4          3                  2
# 394347    467134    63189            21          3                  2
# 250626    467134    63189            21          3                  2
# 99462     794638    50898            24          3                  2
# 145574    794638    50898            24          3                  2
# 311713   1021560    53767             3          3                  2
# 242618   1021560    53767             3          3                  2
# 164581   1112182   202304            84          3                  2
# 273805   1112182   202304            84          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Sí
# Si sí, ¿qué tienen en común? Están duplicadas en par

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
instacart_orders[(instacart_orders['order_dow'] == 3) & (instacart_orders['order_hour_of_day'] == 2)]
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# ¿Qué sugiere este resultado?
#
# * Puede haber alguna falla en el sistema a las 2 am que esté duplicando los pedidos, porque es una hora inusual para comprar, quizás también a esa hora se reinicen los sistemas y podrían sacar a flote ciertos errores en algunos pedidos

# %%
# Elimina los pedidos duplicados
instacart_orders.drop_duplicates(inplace=True)
instacart_orders.head(10)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
# 5   1843871    20084             5          0                 11
# 6   2511640   148233            40          3                  8
# 7   2521283    97711             2          0                 18
# 8   2266494    34954            40          5                 15
# 9    446014    15356             2          4                  8
#
#    days_since_prior_order
# 0                    30.0
# 1                     9.0
# 2                     2.0
# 3                    10.0
# 4                    17.0
# 5                    15.0
# 6                     2.0
# 7                    22.0
# ...

# %%
# Vuelve a verificar si hay filas duplicadas
instacart_orders.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos
#
# * Al eliminar los pedidos duplicados, podemos visualizar mayor orden en posteriores operaciones y podremos mostrar datos relevantes para tomar decisiones

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
instacart_orders['order_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo al identificar los duplicados en `orders`, especialmente aquellos relacionados con pedidos realizados a las 2:00 AM los miércoles!
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Recuerda aplicar `.reset_index(drop=True)` después de `.drop_duplicates()`, lo cual es una buena práctica.
#
# </div>
#
# </div>

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
products.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay ID de departamentos duplicados
products['department_id'].duplicated().sum()
# Out:
# 49673

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
products['product_name'].duplicated().sum()
products['product_name'] = products['product_name'].str.upper()
display(products)
# Out:
#        product_id                                       product_name  \
# 0               1                         CHOCOLATE SANDWICH COOKIES
# 1               2                                   ALL-SEASONS SALT
# 2               3               ROBUST GOLDEN UNSWEETENED OOLONG TEA
# 3               4  SMART ONES CLASSIC FAVORITES MINI RIGATONI WIT...
# 4               5                          GREEN CHILE ANYTIME SAUCE
# ...           ...                                                ...
# 49689       49690                      HIGH PERFORMANCE ENERGY DRINK
# 49690       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 49691       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692       49693                             SPRING WATER BODY WASH
# 49693       49694                            BURRITO- STEAK & CHEESE
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %%
# Revisa si hay nombres duplicados de productos no faltantes

productos_no_faltantes = products[~products['product_name'].isna()]

print(productos_no_faltantes['product_name'].duplicated().sum())
productos_no_faltantes[productos_no_faltantes['product_name'].duplicated(keep=False)].sort_values(by='product_name')
# Out:
# 104
#        product_id                               product_name  aisle_id  \
# 23339       23340  18-IN-1 HEMP PEPPERMINT PURE-CASTILE SOAP        25
# 31844       31845  18-IN-1 HEMP PEPPERMINT PURE-CASTILE SOAP        25
# 19941       19942            AGED BALSAMIC VINEGAR OF MODENA        19
# 13152       13153            AGED BALSAMIC VINEGAR OF MODENA        19
# 24830       24831         ALBACORE SOLID WHITE TUNA IN WATER        95
# ...           ...                                        ...       ...
# 46873       46874                         VITAMIN D3 5000 IU        47
# 21366       21367              WILD SARDINES IN SPRING WATER        95
# 40093       40094              WILD SARDINES IN SPRING WATER        95
# 1826         1827           YAMS CUT SWEET POTATOES IN SYRUP        81
# 38260       38261           YAMS CUT SWEET POTATOES IN SYRUP        81
#
#        department_id
# 23339             11
# 31844             11
# 19941             13
# ...

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# * Encontré ciertos productos guardados doblemente, lo que podría generar problemas al momento de contabilizar ventas o medir cuantitativamente el desempeño del negocio

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# En este paso lo importante es detectar que hay productos con el mismo nombre, pero distintos ID's de producto. Probablemente son productos diferentes por lo que no se tratan como duplicados, luego, la tabla `products` no contiene realmente valores duplicados.
#
# Pero lo interesante es realizar este análisis.
#
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
departments.duplicated().sum() # Revisa si hay filas totalmente duplicadas
# Out:
# 0

# %%
departments['department_id'].duplicated().sum() # Revisa únicamente si hay IDs duplicadas de productos
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# * Se encontraron 0 duplicados en los departamentos, lo que indica que todo está en orden en esa área

# %% [markdown]
# ### `aisles` data frame

# %%
aisles.duplicated().sum() # Revisa si hay filas totalmente duplicadas
# Out:
# 0

# %%
aisles['aisle_id'].duplicated().sum() # Revisa únicamente si hay IDs duplicadas de pasillos
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# * Nuevamente, no hay pasillos duplicados y todo está en orden

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Correcto, no hay duplicados en _departments_ ni en _aisles_.
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
order_products.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# * Descubrí que hay 0 filas duplicadas en el área de pedidos y se puede trabajar con datos limpios

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
order_products[order_products.duplicated(subset=['order_id', 'add_to_cart_order']) & order_products['add_to_cart_order'].notnull()]
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
order_products
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440               17.0          0
# 1          567889        1560                1.0          1
# 2         2261212       26683                1.0          1
# 3          491251        8670               35.0          1
# 4         2571142        1940                5.0          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290               12.0          1
# 4545003   1219554       21914                9.0          0
# 4545004    692640       47766                4.0          1
# 4545005    319435         691                8.0          1
# 4545006   1398151       28733                9.0          0
#
# [4545007 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# No verificaste duplicados en el subconjunto `['order_id', 'product_id']`. Esto es importante porque ningún producto debería aparecer más de una vez por pedido.
#
# Si no utilizas _subset_ para controlar estas columnas por separado, puede que se nos pase por alto.
#
# Sin embargo, tampoco hay duplicados en este caso.
#
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
products['product_name'].isna().sum() # Encuentra los valores ausentes en la columna 'product_name'
# Out:
# 1258

# %%
products[products['product_name'].isnull()]
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
products[(products['product_name'].isnull()) & (products['aisle_id'] != 100)]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# * Tenemos una tabla vacía porque no hay productos ausentes en el pasillo ID 100

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
products[(products['product_name'].isnull()) & (products['department_id'] != 21)]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# * Nuevamente comprobamos que no hay productos ausentes con el ID 21

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.

display(departments[(departments['department_id'] == 21)])
aisles[(aisles['aisle_id'] == 100)]
# Out:
#     department_id department
# 20             21    missing
#     aisle_id    aisle
# 99       100  missing

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.

# %%
#Completa los nombres de productos ausentes con 'Unknown'
products.fillna(value='Unknown', inplace=True)
products['product_name'].value_counts()
# Out:
# Unknown                                    1258
# GREEN TEA WITH GINSENG AND HONEY              3
# SOUR CREAM AND ONION POTATO CHIPS             2
# ORGANIC BALSAMIC VINEGAR OF MODENA            2
# FIRE ROASTED DICED TOMATOES WITH GARLIC       2
#                                            ...
# PREMIUM GOURMET WHITE POPCORN                 1
# TURKEY FORMULA CAT FOOD                       1
# HAWAIIAN BREEZE SCENTED OIL REFILL            1
# HOT GARLIC BAKED SHRIMP FLAVORED CHIPS        1
# VEGGIE BLENDS PURPLE POWER                    1
# Name: product_name, Length: 48333, dtype: int64

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo al identificar los valores ausentes en `product_name` y asociarlos con las columnas `aisle_id` y `department_id`! Reemplazar estos valores con `'Unknown'` es una decisión lógica y adecuada.
#
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
instacart_orders.isnull().sum() # Encuentra los valores ausentes
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
instacart_orders[instacart_orders['order_number'] != 1].isna().sum()
# Out:
# order_id                  0
# user_id                   0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Identificaste correctamente que los valores ausentes en `days_since_prior_order` corresponden a `order_number == 1`! Dejar los valores como `NaN` o usar un valor razonable asegura que los datos se manejen correctamente.
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Sin embargo, recuerda dejar claramente tus comentarios y conclusiones.
#
# </div>
#
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
order_products.isnull().sum() # Encuentra los valores ausentes
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
836
# Out:
# 836

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
orders_null = order_products[order_products['add_to_cart_order'].isnull()]
orders_null.head(5)
# Out:
#        order_id  product_id  add_to_cart_order  reordered
# 737     2449164        5068                NaN          0
# 9926    1968313       43867                NaN          0
# 14394   2926893       11688                NaN          0
# 16418   1717990        4142                NaN          0
# 30114   1959075       42828                NaN          1

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.

orders_null.groupby(by='order_id')['product_id'].count().reset_index(name='product_total').sort_values(by='product_total', ascending=False)
# Out:
#     order_id  product_total
# 1      61355             63
# 67   3308010             51
# 49   2136777             44
# 5     171934             40
# 45   1959075             34
# ..       ...            ...
# 18    888470              1
# 32   1598369              1
# 13    747668              1
# 37   1677118              1
# 0       9310              1
#
# [70 rows x 2 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
order_products['add_to_cart_order'] = order_products['add_to_cart_order'].fillna(999).astype(int)
display(order_products)
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440                 17          0
# 1          567889        1560                  1          1
# 2         2261212       26683                  1          1
# 3          491251        8670                 35          1
# 4         2571142        1940                  5          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290                 12          1
# 4545003   1219554       21914                  9          0
# 4545004    692640       47766                  4          1
# 4545005    319435         691                  8          1
# 4545006   1398151       28733                  9          0
#
# [4545007 rows x 4 columns]

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo!
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# No calculaste los valores `min` y `max` de `add_to_cart_order`, ni verificaste que los pedidos con más de 64 artículos sean plausibles.
#
# Un valor mínimo de 1 tiene sentido porque cada pedido necesita, al menos, 1 artículo. Pero, un valor máximo de 64 resulta un tanto curioso. No hay ninguna razón (que no sea mera suerte) para que cualquiera pidiera más de 64 artículos en un pedido.
#
# Además, 64 enciende las alarmas porque es un número de base 2 muy común que surgen con asuntos de informática. Esta es una pista de que quizás el tipo database para esa columna solo admite almacenamiento de 64 bits.
#
# Luego, como era de esperarse, cada pedido relacionado con un valor ausente tiene más de 64 artículos en ella.
# </div>
# Ya que no podemos saber en qué pedido se agregaron al carrito los artículos con valores ausentes para aquellos pedidos con más de 65 artículos, lo correcto es completar los valores ausentes con un valor de marcador de posición numérico que no pueda confundirse con daros reales; por ejemplo, 999.
#
# </div>

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
instacart_orders['order_hour_of_day'].unique()
# Out:
# array([13, 12, 19, 20, 11,  8, 18, 15, 16,  9, 22, 10,  0, 14, 17,  1,  7,
#         6,  2, 21,  3, 23,  5,  4])

# %%
instacart_orders['order_dow'].unique()
# Out:
# array([6, 5, 0, 4, 3, 1, 2])

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo revisando los valores únicos.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
hora_del_dia = instacart_orders['order_hour_of_day'].value_counts().sort_index()

hora_del_dia.plot(kind='bar',
                 xlabel='hora',
                 ylabel='número de compras')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# * Encontré que las personas hacen más órdenes entre las 9 am y 4 pm

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo al usar un gráfico de barras para visualizar los datos! Además, la comunicación de los resultados es clara y precisa: identificaste correctamente que la mayoría de los pedidos ocurren entre las 9:00 AM y las 5:00 PM, con picos a las 10:00 AM y las 3:00 PM. Esto proporciona una gran perspectiva sobre el comportamiento del cliente.
#
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
dia_semana = instacart_orders['order_dow'].value_counts().sort_index()

dia_semana.plot(kind='bar',
                 xlabel='dia de la semana',
                 ylabel='número de compras')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# * Por lo regular los Domingos y Lunes hay más órdenes de compra

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# El uso de un gráfico de barras para representar los datos es acertado y ayuda a visualizar las tendencias claramente. Tu comunicación de resultados también es precisa: identificaste correctamente que, asumiendo que el domingo es 0, la mayoría de los pedidos se realizan el domingo y el lunes.
#
# </div>

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
tiempo_de_espera = instacart_orders['days_since_prior_order'].value_counts().sort_index()

tiempo_de_espera.plot(kind='bar',
                 xlabel='días de espera',
                 ylabel='pedidos')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# * Los clientes suelen hacer sus compras una vez por semana y dentro de un mes

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo al visualizar los datos! Además, tu interpretación de los resultados es sólida
#
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
miercoles_y_sabados = instacart_orders[(instacart_orders['order_dow'] == 3) | (instacart_orders['order_dow'] == 6)]

sns.histplot(data=miercoles_y_sabados, x='order_hour_of_day', hue='order_dow', palette='viridis', binwidth=1, multiple='dodge')
# Out:
# <AxesSubplot:xlabel='order_hour_of_day', ylabel='Count'>

# %%
numero_ordenes = instacart_orders.groupby(by='user_id')['order_id'].nunique().reset_index(name='conteo_pedidos').sort_values(by='user_id', ascending=False)
numero_ordenes.head(10)

sns.histplot(data=numero_ordenes, x='conteo_pedidos', palette='viridis', binwidth=1, multiple='dodge')
# Out:
# <AxesSubplot:xlabel='conteo_pedidos', ylabel='Count'>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# * Por lo regular, los días miércoles y sábados tienen tráfico de clientes muy similares a las mismas horas con algunas pequeñas diferencias

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo!
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Aunque no mencionaste la ligera disminución de 11h a 13h los miércoles, que está ausente los sábados. Te sugiero revisar estos puntos para mejorar tu análisis.
#
# </div>
#
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
numero_ordenes = instacart_orders.groupby(by='user_id')['order_id'].nunique().reset_index(name='conteo_pedidos').sort_values(by='user_id', ascending=False)
numero_ordenes.head(10)
# Out:
#         user_id  conteo_pedidos
# 157436   206209               2
# 157435   206208               9
# 157434   206207               5
# 157433   206206               7
# 157432   206203               1
# 157431   206202               3
# 157430   206201               4
# 157429   206200               3
# 157428   206199               3
# 157427   206198               2

# %% [markdown]
# Escribe aquí tus conclusiones
#
# * Por lo regular hacen entre 2 y 9 pedidos cada cliente

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# En este caso podrías utilizar un histograma para visualizar correctamente los datos.
#
# Un histograma es adecuado cuando se desea analizar la distribución de un conjunto de datos continuos, es decir, aquellos que pueden tomar cualquier valor dentro de un rango. Se utiliza para representar la frecuencia con la que ocurren ciertos valores dentro de intervalos o clases, permitiendo identificar patrones como la simetría, la dispersión o la presencia de sesgos en los datos. Es especialmente útil en estadística para entender cómo se distribuyen variables como alturas, edades, tiempos de espera o calificaciones en un examen. A diferencia del gráfico de barras, en el histograma las barras están juntas, ya que los datos representados son continuos y no categorías separadas.
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
top_20 = order_products.groupby(by='product_id')['order_id'].count().reset_index(name='conteo_productos').sort_values(by='conteo_productos', ascending=False)
top_20_nombres = pd.merge(top_20, products[['product_name', 'product_id']], on='product_id', how='left')
top_20_nombres.head(20)
# Out:
#     product_id  conteo_productos              product_name
# 0        24852             66050                    BANANA
# 1        13176             53297    BAG OF ORGANIC BANANAS
# 2        21137             37039      ORGANIC STRAWBERRIES
# 3        21903             33971      ORGANIC BABY SPINACH
# 4        47209             29773      ORGANIC HASS AVOCADO
# 5        47766             24689           ORGANIC AVOCADO
# 6        47626             21495               LARGE LEMON
# 7        16797             20018              STRAWBERRIES
# 8        26209             19690                     LIMES
# 9        27845             19600        ORGANIC WHOLE MILK
# 10       27966             19197       ORGANIC RASPBERRIES
# 11       22935             15898      ORGANIC YELLOW ONION
# 12       24964             15292            ORGANIC GARLIC
# 13       45007             14584          ORGANIC ZUCCHINI
# 14       39275             13879       ORGANIC BLUEBERRIES
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Correcto! Los productos populares se listan correctamente.
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# En el análisis de productos más populares ([B3]), sería útil añadir una visualización tipo gráfico de barras para complementar la tabla y facilitar una lectura rápida del ranking. Esto también permitiría detectar patrones visuales como posibles productos muy por encima del resto.
#
# </div>
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# * Los datos muestran que los clientes ordenan más frutas y verduras

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
articulos_comprados = order_products.groupby(by='order_id')['product_id'].count().reset_index(name='conteo_productos')

articulos_comprados.head(10)
# Out:
#    order_id  conteo_productos
# 0         4                13
# 1         9                15
# 2        11                 5
# 3        19                 3
# 4        20                 8
# 5        31                10
# 6        48                 8
# 7        56                10
# 8        61                12
# 9        68                 9

# %%
articulos_comprados['conteo_productos'].describe()
# Out:
# count    450046.000000
# mean         10.098983
# std           7.540206
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          14.000000
# max         127.000000
# Name: conteo_productos, dtype: float64

# %%
sns.histplot(data=articulos_comprados, x='conteo_productos', palette='viridis', binwidth=1, multiple='dodge')
# Out:
# <AxesSubplot:xlabel='conteo_productos', ylabel='Count'>

# %%
articulos_comprados[articulos_comprados['conteo_productos'] > 45]
# Out:
#         order_id  conteo_productos
# 223         1509                52
# 1274        9310                65
# 2096       15508                47
# 3501       26531                46
# 3623       27426                49
# ...          ...               ...
# 447377   3400760                48
# 447713   3403261                49
# 448025   3405532                51
# 448442   3408791                54
# 448607   3410019                54
#
# [901 rows x 2 columns]

# %% [markdown]
# Escribe aquí tus conclusiones
#
# * Cada cliente se lleva 10 productos en promedio por pedido

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo! Efectivamente vemos que las personas generalmente realizan pedidos de entre 1 y 10 artículos.
#
# </div>

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
productos_frecuentes = order_products.groupby(by='product_id')['reordered'].sum().reset_index(name='productos_frecuentes').sort_values(by='productos_frecuentes', ascending=False)
productos_frecuentes = pd.merge(productos_frecuentes, products[['product_name', 'product_id']], on='product_id', how='left')
productos_frecuentes.head(20)
# Out:
#     product_id  productos_frecuentes              product_name
# 0        24852                 55763                    BANANA
# 1        13176                 44450    BAG OF ORGANIC BANANAS
# 2        21137                 28639      ORGANIC STRAWBERRIES
# 3        21903                 26233      ORGANIC BABY SPINACH
# 4        47209                 23629      ORGANIC HASS AVOCADO
# 5        47766                 18743           ORGANIC AVOCADO
# 6        27845                 16251        ORGANIC WHOLE MILK
# 7        47626                 15044               LARGE LEMON
# 8        27966                 14748       ORGANIC RASPBERRIES
# 9        16797                 13945              STRAWBERRIES
# 10       26209                 13327                     LIMES
# 11       22935                 11145      ORGANIC YELLOW ONION
# 12       24964                 10411            ORGANIC GARLIC
# 13       45007                 10076          ORGANIC ZUCCHINI
# ...

# %% [markdown]
# Escribe aquí tus conclusiones
#
# * Nuevamente se vuelven a vender más frutas y verduras

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Impecable, los resultados son los esperados.
#
# </div>

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
productos_reordenados = order_products.groupby(by='product_id')['reordered'].mean().reset_index(name='productos_reordenados').sort_values(by='productos_reordenados', ascending=False)
productos_reordenados.head(50)
productos_reordenados[productos_reordenados['productos_reordenados'] < 1]
# Out:
#        product_id  productos_reordenados
# 9338        10236               0.952381
# 5002         5470               0.947368
# 8092         8867               0.944444
# 19039       20783               0.944444
# 24813       27041               0.937500
# ...           ...                    ...
# 9559        10485               0.000000
# 34562       37690               0.000000
# 9558        10484               0.000000
# 9548        10474               0.000000
# 39401       42984               0.000000
#
# [43764 rows x 2 columns]

# %% [markdown]
# Escribe aquí tus conclusiones
#
# * Entre 93% y 95% de los productos se vuelven a reordenar

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
clientes_recurrentes = pd.merge(instacart_orders, order_products[['product_id', 'reordered', 'order_id']], on='order_id', how='right').sort_values(by='order_id')
proporcion_clientes = clientes_recurrentes.groupby(by='user_id')['reordered'].mean().reset_index(name='proporcion_clientes').sort_values(by='proporcion_clientes', ascending=False)
proporcion_clientes.sample(10)
# Out:
#         user_id  proporcion_clientes
# 149145   205526             0.553571
# 3576       4877             0.871795
# 8344      11445             0.916667
# 118215   163101             0.465116
# 2991       4099             0.555556
# 145720   200811             0.375000
# 100835   139198             0.400000
# 9957      13663             0.291667
# 64582     89127             0.500000
# 42077     58151             0.793103

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo. Los resultados son los esperados.
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Nota que sería muy interesante crear un histograma de la tasa de repetición.
#
# </div>
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# * Los clientes vuelven a reordenar en un 50% sus productos nuevamente

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
articulos_principales = order_products.groupby(by='product_id')['add_to_cart_order'].count().reset_index(name='articulos principales').sort_values(by='articulos principales', ascending=False)
articulos_principales = pd.merge(articulos_principales, products[['product_id', 'product_name']], on='product_id', how='left')
articulos_principales.head(20)
# Out:
#     product_id  articulos principales              product_name
# 0        24852                  66050                    BANANA
# 1        13176                  53297    BAG OF ORGANIC BANANAS
# 2        21137                  37039      ORGANIC STRAWBERRIES
# 3        21903                  33971      ORGANIC BABY SPINACH
# 4        47209                  29773      ORGANIC HASS AVOCADO
# 5        47766                  24689           ORGANIC AVOCADO
# 6        47626                  21495               LARGE LEMON
# 7        16797                  20018              STRAWBERRIES
# 8        26209                  19690                     LIMES
# 9        27845                  19600        ORGANIC WHOLE MILK
# 10       27966                  19197       ORGANIC RASPBERRIES
# 11       22935                  15898      ORGANIC YELLOW ONION
# 12       24964                  15292            ORGANIC GARLIC
# 13       45007                  14584          ORGANIC ZUCCHINI
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Por un lado, el nombre de la columna 'articulos principales' no es del todo representativo. Por otro lado, los conteos no son los esperados.
#
# En este caso, se pedía mostrar el total de veces que cada producto fué el primero en ser añadido. Es decir, algo como esto:
#
#     df_merge = order_products.merge(products)
#     first_in_cart = df_merge[df_merge['add_to_cart_order'] == 1]
#
# Luego podrías completar el código para hacer el conteo por producto.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# * Basándonos en el análisis, les llaman la atención frutas y verduras a los clientes. Esto podría atribuirse a que son más accesibles o también a la calidad de los productos

# %% [markdown]
# ### Conclusion general del proyecto:

# %%
Este análisis me enseñó a profundizar en áreas 
del procesamiento de datos y hacerlos visuales para tomar decisiones sobre las preferencias de los clientes y lo que más compran. 
    Eso influirá en la toma de decisiones de la empresa
